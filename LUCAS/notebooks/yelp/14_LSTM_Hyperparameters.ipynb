# %% [markdown]
# # LSTM HyperParam Tuning: Stacked biLSTM(100) with variational dropout

# %% [markdown]
# In this notebook, I used a Colab TPU to fine-tune hyperparameters of our LSTM network, based off research in sequence classification using LSTM networks [Reimers, 2017](https://arxiv.org/abs/1707.06799). The research showed that using word embeddings, 2 stacked bidirectional hidden layers, 64-200 nodes and recurrent dropout was the best structure for a deep LSTM network for sequence classification. In this notebook I will implement this architcture and see how it performs on the YelpZIP dataset.
#
# First I will import necessary libraries and connect to Google Cloud bucket, the TPU and Tensorboard.

# %%
import os
import pprint
import tensorflow as tf
import re
import pandas as pd
import numpy as np
import random
import subprocess
import gzip
import string
import sys
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Embedding, LSTM
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras import optimizers
from tensorflow.keras import layers
import codecs
from tensorboardcolab import *
import shutil

# %%
#clean out the directory
tbc=TensorBoardColab(startup_waiting_time=10)

if 'COLAB_TPU_ADDR' not in os.environ:
  print('ERROR: Not connected to a TPU runtime; please see the first cell in this notebook for instructions!')
else:
  tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
  print ('TPU address is', tpu_address)

  with tf.Session(tpu_address) as session:
    devices = session.list_devices()
    
  print('TPU devices:')
  pprint.pprint(devices)

OUTPUT_DIR = 'lstm-finetuning'#@param {type:"string"}
#@markdown Whether or not to clear/delete the directory and create a new one
DO_DELETE = False #@param {type:"boolean"}
#@markdown Set USE_BUCKET and BUCKET if you want to (optionally) store model output on GCP bucket.
USE_BUCKET = True #@param {type:"boolean"}
BUCKET = 'lucas0' #@param {type:"string"}

if USE_BUCKET:
  OUTPUT_DIR = 'gs://{}/{}'.format(BUCKET, OUTPUT_DIR)
  from google.colab import auth
  auth.authenticate_user()

if DO_DELETE:
  try:
    tf.gfile.DeleteRecursively(OUTPUT_DIR)
  except:
    # Doesn't matter if the directory didn't exist
    pass
tf.gfile.MakeDirs(OUTPUT_DIR)
print('***** Model output directory: {} *****'.format(OUTPUT_DIR))
os.mkdir('./Graph')
# Out:
# Wait for 10 seconds...
# TensorBoard link:
# https://4348060c.ngrok.io
# TPU address is grpc://10.119.99.34:8470
# TPU devices:
# [_DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:CPU:0, CPU, -1, 11798704124795778594),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 6325436278654816791),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 17327105947192632281),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 8193999110742063840),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 13551189176767611107),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 4452687537149654827),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 10157693069563783220),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 1122971557887119691),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 962774712908111032),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 2171603634475846081),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 17179869184, 16540263404153612352)]
# ***** Model output directory: gs://lucas0/lstm-finetuning *****

# %% [markdown]
# We then download the YelpZIP dataset from our Google Cloud Bucket, and parse it into a dictionary.

# %%
def download_and_load_dataset(force_download=False):
  dataset = tf.keras.utils.get_file(
      fname="yelpZIP.txt", 
      origin="https://storage.googleapis.com/lucas0/yelpZIP.txt", 
      extract=False)
  dfile = open(dataset).readlines()
  return dfile

reviews = download_and_load_dataset()

data = {}
data['review'] = []
data['deceptive'] = []

for x in reviews:
  x = eval(x)
  data['review'].append(x[0])
  data['deceptive'].append(1 if x[1] else 0)

dataDict = pd.DataFrame.from_dict(data)

# %% [markdown]
# I then fit a Tokenizer on the dataset and pad the sequences to be the same length.

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()
tokenizer.fit_on_texts(data['review'])

# %%
corpus_words = tokenizer.word_index
corpus_vocab_size = len(corpus_words)+1

# %%
from keras.preprocessing.sequence import pad_sequences

predictors_sequences = pad_sequences(tokenizer.texts_to_sequences(data['review']))
max_len = max([len(x) for x in predictors_sequences])

# %% [markdown]
# Then I downloaded the Google pretrained word2vec from our bucket and created the embeddings matrix.

# %%
import gensim
tf.keras.utils.get_file(
      fname="GoogleNews-vectors-negative300.bin", 
      origin="https://storage.googleapis.com/lucas0/GoogleNews-vectors-negative300.bin", 
      extract=False)
# Out:
# '/root/.keras/datasets/GoogleNews-vectors-negative300.bin'

# %%
word_vectors = gensim.models.KeyedVectors.load_word2vec_format("~/.keras/datasets/GoogleNews-vectors-negative300.bin", binary=True)

# %%
embedding_length = word_vectors.vector_size
embedding_matrix = np.zeros((corpus_vocab_size, embedding_length))
for word, index in corpus_words.items():
  if word in word_vectors.vocab:
    embedding_matrix[index] = np.array(word_vectors[word], dtype=np.float32)

# %% [markdown]
# Now I create the first model according to the reccomended network archiecture. Variational dropout is implemented in Keras by using the recurrent_dropout parameter of the LSTM layer. When using a TPU, a cross-shard optimizer must be used to split the training over the 8 TPU cores. Then the keras TPU contrib module must be used to convert the Keras model to a TF TPU model.

# %%
def get_lstm_wv_model(load_checkpoint=False):
  model = Sequential([
        Embedding(corpus_vocab_size, embedding_length, weights=[embedding_matrix], input_length=max_len, trainable=False),
        keras.layers.Bidirectional(LSTM(100, recurrent_dropout=0.2, return_sequences=True)),
        keras.layers.Bidirectional(LSTM(100, recurrent_dropout=0.2)),
        Dense(1, activation='sigmoid')
  ])
  from keras.utils import plot_model
  plot_model(model, to_file='model.png', show_shapes=True)
  from IPython.display import Image
  Image(filename='model.png')
  if load_checkpoint:
    model.load_weights('./Mar-24-all-01-0.6957.hdf5')
  train_op = tf.train.AdamOptimizer()
  optimizer = tf.contrib.tpu.CrossShardOptimizer(train_op)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  return tf.contrib.tpu.keras_to_tpu_model(
    model,
    strategy=tf.contrib.tpu.TPUDistributionStrategy(
        tf.contrib.cluster_resolver.TPUClusterResolver(tpu_address)))

# %% [markdown]
# I then define the cross-validate function that Stefan wrote, create a checkpoint and early stopping callback.

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import TensorBoard


def run_cross_validate(get_model, X, y, cv=5, categorical=False,
                       add_target_dim=False, verbose=1, epochs=12, batch_size = 32, validation_split=0.3, shuffle=True):
  
  skfSplitter = StratifiedKFold(n_splits=cv, shuffle=shuffle)
  
  metrics = {
    "accuracies": [],
  }
    
  for train_indices, test_indices in skfSplitter.split(X, y):
    training_X = np.array([X[x] for x in train_indices])
    training_y = np.array([y[x] for x in train_indices])
    x_train, x_valid, y_train, y_valid = train_test_split(training_X, training_y, test_size=0.3, shuffle= True)
    test_X = np.array([X[x] for x in test_indices])
    test_y = np.array([y[x] for x in test_indices])
    
    if categorical:
      training_y = to_categorical(training_y)
      test_y = to_categorical(test_y)
    if add_target_dim:
      training_y = np.array([[y] for y in training_y])
      test_y = np.array([[y] for y in test_y])
    
    model = get_model()
    print("Fitting with: ", np.array(x_train).shape, "labels",
          np.array(y_train).shape)
    filepath="Mar-24-all-{epoch:02d}-{val_acc:.4f}.hdf5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    early_stopping = EarlyStopping(monitor='val_acc', patience=8)
    sess = tf.Session()
    train_writer = tbc.get_writer();
    train_writer.add_graph(sess.graph)
    
    model.fit(np.array(x_train), y_train, epochs=epochs, batch_size=batch_size,
              validation_data=(x_valid, y_valid), verbose=verbose,
              callbacks=[checkpoint, early_stopping], shuffle=shuffle)
    metrics["accuracies"].append(model.evaluate(np.array(test_X), test_y)[1])
  return metrics

# %% [markdown]
# Now we train the model. I use a batch size of 64, 20 epochs and 5 folds.
#
# Note: The experiment did not complete in the 12 allotted hours on Colab, so I loaded in the checkpointed model and started the training again for another 2 folds. The validation accuracy was 0.6665 +- 0.035, with a val_loss of .62.

# %%
# from tensorflow.contrib.tpu.python.tpu import tpu_function
# tpu_function.get_tpu_context().set_number_of_shards(8)

rnn_wv_scores = run_cross_validate(get_lstm_wv_model, predictors_sequences, data['deceptive'], cv=5, verbose=1, epochs=20, batch_size=64, shuffle=True)
print(rnn_wv_scores)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py:4010: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# INFO:tensorflow:Querying Tensorflow master (grpc://10.14.208.42:8470) for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, -1, 1403723184091569382)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 10463534745533730844)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 17881866803021330038)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 3534345446672985863)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 13091818805743805186)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 1215454904928374953)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 2231771749928170029)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 1221604824504221278)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 14477528328139840800)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 10270923715066972461)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 17179869184, 6584934046370716661)
# WARNING:tensorflow:tpu_model (from tensorflow.contrib.tpu.python.tpu.keras_support) is experimental and may change or be removed at any time, and without warning.
# Fitting with:  (90121, 1006) labels (90121,)
# Train on 90121 samples, validate on 38624 samples
# Epoch 1/20
# INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(8,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(8, 1006), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(8, 1), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/tpu/python/tpu/keras_support.py:302: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 8.38670015335083 secs
# INFO:tensorflow:Setting weights on TPU model.
# 90048/90121 [============================>.] - ETA: 0s - loss: 0.6730 - acc: 0.5782INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(1,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(1, 1006), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(1, 1), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 17.27760672569275 secs
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.6730 - acc: 0.5783INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(8,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(8, 1006), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(8, 1), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 16.441497325897217 secs
# INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(4,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(4, 1006), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(4, 1), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 25.395866632461548 secs
#
# Epoch 00001: val_acc improved from -inf to 0.64328, saving model to Mar-24-all-01-0.6433.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90121/90121 [==============================] - 737s 8ms/sample - loss: 0.6730 - acc: 0.5783 - val_loss: 0.6354 - val_acc: 0.6433
# Epoch 2/20
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.6418 - acc: 0.6368
# Epoch 00002: val_acc improved from 0.64328 to 0.66021, saving model to Mar-24-all-02-0.6602.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90121/90121 [==============================] - 617s 7ms/sample - loss: 0.6418 - acc: 0.6369 - val_loss: 0.6261 - val_acc: 0.6602
# Epoch 3/20
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.6196 - acc: 0.6596
# Epoch 00003: val_acc improved from 0.66021 to 0.66655, saving model to Mar-24-all-03-0.6666.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90121/90121 [==============================] - 618s 7ms/sample - loss: 0.6196 - acc: 0.6596 - val_loss: 0.6131 - val_acc: 0.6666
# Epoch 4/20
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.6310 - acc: 0.6444
# Epoch 00004: val_acc did not improve from 0.66655
# 90121/90121 [==============================] - 605s 7ms/sample - loss: 0.6310 - acc: 0.6445 - val_loss: 0.6260 - val_acc: 0.6552
# Epoch 5/20
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.6197 - acc: 0.6583
# Epoch 00005: val_acc did not improve from 0.66655
# 90121/90121 [==============================] - 604s 7ms/sample - loss: 0.6197 - acc: 0.6583 - val_loss: 0.6154 - val_acc: 0.6641
# Epoch 6/20
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.6125 - acc: 0.6653
# Epoch 00006: val_acc improved from 0.66655 to 0.66888, saving model to Mar-24-all-06-0.6689.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90121/90121 [==============================] - 619s 7ms/sample - loss: 0.6125 - acc: 0.6653 - val_loss: 0.6096 - val_acc: 0.6689
# Epoch 7/20
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.6051 - acc: 0.6716
# Epoch 00007: val_acc did not improve from 0.66888
# 90121/90121 [==============================] - 603s 7ms/sample - loss: 0.6051 - acc: 0.6716 - val_loss: 0.6113 - val_acc: 0.6687
# Epoch 8/20
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.5988 - acc: 0.6759
# Epoch 00008: val_acc improved from 0.66888 to 0.67414, saving model to Mar-24-all-08-0.6741.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90121/90121 [==============================] - 619s 7ms/sample - loss: 0.5988 - acc: 0.6759 - val_loss: 0.6021 - val_acc: 0.6741
# Epoch 9/20
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.5907 - acc: 0.6836
# Epoch 00009: val_acc improved from 0.67414 to 0.67453, saving model to Mar-24-all-09-0.6745.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90121/90121 [==============================] - 620s 7ms/sample - loss: 0.5907 - acc: 0.6836 - val_loss: 0.6022 - val_acc: 0.6745
# Epoch 10/20
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.5814 - acc: 0.6922
# Epoch 00010: val_acc improved from 0.67453 to 0.67567, saving model to Mar-24-all-10-0.6757.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90121/90121 [==============================] - 621s 7ms/sample - loss: 0.5814 - acc: 0.6922 - val_loss: 0.6014 - val_acc: 0.6757
# Epoch 11/20
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.5748 - acc: 0.6970
# Epoch 00011: val_acc did not improve from 0.67567
# 90121/90121 [==============================] - 605s 7ms/sample - loss: 0.5748 - acc: 0.6970 - val_loss: 0.6067 - val_acc: 0.6743
# Epoch 12/20
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.5613 - acc: 0.7069
# Epoch 00012: val_acc did not improve from 0.67567
# 90121/90121 [==============================] - 604s 7ms/sample - loss: 0.5613 - acc: 0.7069 - val_loss: 0.6121 - val_acc: 0.6697
# Epoch 13/20
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.5488 - acc: 0.7164
# Epoch 00013: val_acc did not improve from 0.67567
# 90121/90121 [==============================] - 605s 7ms/sample - loss: 0.5489 - acc: 0.7163 - val_loss: 0.6212 - val_acc: 0.6682
# Epoch 14/20
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.5319 - acc: 0.7272
# Epoch 00014: val_acc did not improve from 0.67567
# 90121/90121 [==============================] - 607s 7ms/sample - loss: 0.5319 - acc: 0.7272 - val_loss: 0.6349 - val_acc: 0.6687
# Epoch 15/20
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.5161 - acc: 0.7384
# Epoch 00015: val_acc did not improve from 0.67567
# 90121/90121 [==============================] - 607s 7ms/sample - loss: 0.5161 - acc: 0.7383 - val_loss: 0.6423 - val_acc: 0.6607
# Epoch 16/20
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.4970 - acc: 0.7516
# Epoch 00016: val_acc did not improve from 0.67567
# 90121/90121 [==============================] - 607s 7ms/sample - loss: 0.4970 - acc: 0.7516 - val_loss: 0.6659 - val_acc: 0.6624
# 32160/32188 [============================>.] - ETA: 0s - loss: 0.6692 - acc: 0.6596INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(3,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(3, 1006), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(3, 1), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 46.465561866760254 secs
# 32188/32188 [==============================] - 169s 5ms/sample - loss: 0.6693 - acc: 0.6596
# INFO:tensorflow:Querying Tensorflow master (grpc://10.14.208.42:8470) for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, -1, 1403723184091569382)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 10463534745533730844)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 17881866803021330038)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 3534345446672985863)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 13091818805743805186)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 1215454904928374953)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 2231771749928170029)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 1221604824504221278)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 14477528328139840800)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 10270923715066972461)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 17179869184, 6584934046370716661)
# WARNING:tensorflow:tpu_model (from tensorflow.contrib.tpu.python.tpu.keras_support) is experimental and may change or be removed at any time, and without warning.
# Fitting with:  (90122, 1006) labels (90122,)
# Train on 90122 samples, validate on 38624 samples
# Epoch 1/20
# INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(8,), dtype=tf.int32, name='core_id_20'), TensorSpec(shape=(8, 1006), dtype=tf.float32, name='embedding_1_input_10'), TensorSpec(shape=(8, 1), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_1_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 34.015042781829834 secs
# INFO:tensorflow:Setting weights on TPU model.
# 90048/90122 [============================>.] - ETA: 0s - loss: 0.6691 - acc: 0.5896INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(1,), dtype=tf.int32, name='core_id_20'), TensorSpec(shape=(1, 1006), dtype=tf.float32, name='embedding_1_input_10'), TensorSpec(shape=(1, 1), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_1_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 52.52677321434021 secs
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6690 - acc: 0.5897INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(8,), dtype=tf.int32, name='core_id_30'), TensorSpec(shape=(8, 1006), dtype=tf.float32, name='embedding_1_input_10'), TensorSpec(shape=(8, 1), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_1_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 65.13723659515381 secs
# INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(4,), dtype=tf.int32, name='core_id_30'), TensorSpec(shape=(4, 1006), dtype=tf.float32, name='embedding_1_input_10'), TensorSpec(shape=(4, 1), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_1_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 85.40592813491821 secs
#
# Epoch 00001: val_acc improved from -inf to 0.63681, saving model to Mar-24-all-01-0.6368.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90122/90122 [==============================] - 1032s 11ms/sample - loss: 0.6690 - acc: 0.5897 - val_loss: 0.6463 - val_acc: 0.6368
# Epoch 2/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6510 - acc: 0.6207
# Epoch 00002: val_acc improved from 0.63681 to 0.65625, saving model to Mar-24-all-02-0.6562.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90122/90122 [==============================] - 651s 7ms/sample - loss: 0.6510 - acc: 0.6207 - val_loss: 0.6260 - val_acc: 0.6562
# Epoch 3/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6276 - acc: 0.6498
# Epoch 00003: val_acc improved from 0.65625 to 0.66122, saving model to Mar-24-all-03-0.6612.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90122/90122 [==============================] - 653s 7ms/sample - loss: 0.6276 - acc: 0.6498 - val_loss: 0.6160 - val_acc: 0.6612
# Epoch 4/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6146 - acc: 0.6628
# Epoch 00004: val_acc improved from 0.66122 to 0.66430, saving model to Mar-24-all-04-0.6643.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90122/90122 [==============================] - 654s 7ms/sample - loss: 0.6146 - acc: 0.6627 - val_loss: 0.6126 - val_acc: 0.6643
# Epoch 5/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6059 - acc: 0.6697
# Epoch 00005: val_acc improved from 0.66430 to 0.67088, saving model to Mar-24-all-05-0.6709.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90122/90122 [==============================] - 656s 7ms/sample - loss: 0.6059 - acc: 0.6697 - val_loss: 0.6092 - val_acc: 0.6709
# Epoch 6/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6007 - acc: 0.6748
# Epoch 00006: val_acc did not improve from 0.67088
# 90122/90122 [==============================] - 607s 7ms/sample - loss: 0.6008 - acc: 0.6748 - val_loss: 0.6100 - val_acc: 0.6671
# Epoch 7/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.5967 - acc: 0.6779
# Epoch 00007: val_acc improved from 0.67088 to 0.67619, saving model to Mar-24-all-07-0.6762.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90122/90122 [==============================] - 660s 7ms/sample - loss: 0.5967 - acc: 0.6779 - val_loss: 0.6038 - val_acc: 0.6762
# Epoch 8/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.5920 - acc: 0.6816
# Epoch 00008: val_acc improved from 0.67619 to 0.67720, saving model to Mar-24-all-08-0.6772.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90122/90122 [==============================] - 662s 7ms/sample - loss: 0.5920 - acc: 0.6815 - val_loss: 0.6021 - val_acc: 0.6772
# Epoch 9/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.5856 - acc: 0.6867
# Epoch 00009: val_acc did not improve from 0.67720
# 90122/90122 [==============================] - 607s 7ms/sample - loss: 0.5856 - acc: 0.6867 - val_loss: 0.6015 - val_acc: 0.6768
# Epoch 10/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.5898 - acc: 0.6825
# Epoch 00010: val_acc did not improve from 0.67720
# 90122/90122 [==============================] - 608s 7ms/sample - loss: 0.5898 - acc: 0.6825 - val_loss: 0.6117 - val_acc: 0.6683
# Epoch 11/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.5729 - acc: 0.6977
# Epoch 00011: val_acc did not improve from 0.67720
# 90122/90122 [==============================] - 607s 7ms/sample - loss: 0.5729 - acc: 0.6976 - val_loss: 0.6103 - val_acc: 0.6709
# Epoch 12/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.5719 - acc: 0.6980
# Epoch 00012: val_acc did not improve from 0.67720
# 90122/90122 [==============================] - 608s 7ms/sample - loss: 0.5719 - acc: 0.6981 - val_loss: 0.6234 - val_acc: 0.6660
# Epoch 13/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6134 - acc: 0.6620
# Epoch 00013: val_acc did not improve from 0.67720
# 90122/90122 [==============================] - 608s 7ms/sample - loss: 0.6134 - acc: 0.6620 - val_loss: 0.6256 - val_acc: 0.6489
# Epoch 14/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6129 - acc: 0.6619
# Epoch 00014: val_acc did not improve from 0.67720
# 90122/90122 [==============================] - 608s 7ms/sample - loss: 0.6129 - acc: 0.6619 - val_loss: 0.6217 - val_acc: 0.6550
# 32160/32187 [============================>.] - ETA: 0s - loss: 0.6204 - acc: 0.6611INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(3,), dtype=tf.int32, name='core_id_30'), TensorSpec(shape=(3, 1006), dtype=tf.float32, name='embedding_1_input_10'), TensorSpec(shape=(3, 1), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_1_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 140.66227841377258 secs
# 32187/32187 [==============================] - 271s 8ms/sample - loss: 0.6203 - acc: 0.6612
# INFO:tensorflow:Querying Tensorflow master (grpc://10.14.208.42:8470) for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, -1, 1403723184091569382)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 10463534745533730844)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 17881866803021330038)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 3534345446672985863)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 13091818805743805186)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 1215454904928374953)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 2231771749928170029)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 1221604824504221278)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 14477528328139840800)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 10270923715066972461)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 17179869184, 6584934046370716661)
# WARNING:tensorflow:tpu_model (from tensorflow.contrib.tpu.python.tpu.keras_support) is experimental and may change or be removed at any time, and without warning.
# Fitting with:  (90122, 1006) labels (90122,)
# Train on 90122 samples, validate on 38625 samples
# Epoch 1/20
# INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(8,), dtype=tf.int32, name='core_id_40'), TensorSpec(shape=(8, 1006), dtype=tf.float32, name='embedding_2_input_10'), TensorSpec(shape=(8, 1), dtype=tf.float32, name='dense_2_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_2_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 72.60080361366272 secs
# INFO:tensorflow:Setting weights on TPU model.
# 90048/90122 [============================>.] - ETA: 0s - loss: 0.6868 - acc: 0.5425INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(1,), dtype=tf.int32, name='core_id_40'), TensorSpec(shape=(1, 1006), dtype=tf.float32, name='embedding_2_input_10'), TensorSpec(shape=(1, 1), dtype=tf.float32, name='dense_2_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_2_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 101.41473388671875 secs
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6868 - acc: 0.5425INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(8,), dtype=tf.int32, name='core_id_50'), TensorSpec(shape=(8, 1006), dtype=tf.float32, name='embedding_2_input_10'), TensorSpec(shape=(8, 1), dtype=tf.float32, name='dense_2_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_2_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 134.52966260910034 secs
# INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(4,), dtype=tf.int32, name='core_id_50'), TensorSpec(shape=(4, 1006), dtype=tf.float32, name='embedding_2_input_10'), TensorSpec(shape=(4, 1), dtype=tf.float32, name='dense_2_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_2_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 172.05501747131348 secs
#
# Epoch 00001: val_acc improved from -inf to 0.55551, saving model to Mar-24-all-01-0.5555.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90122/90122 [==============================] - 1445s 16ms/sample - loss: 0.6868 - acc: 0.5425 - val_loss: 0.6828 - val_acc: 0.5555
# Epoch 2/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6635 - acc: 0.6029
# Epoch 00002: val_acc improved from 0.55551 to 0.63771, saving model to Mar-24-all-02-0.6377.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90122/90122 [==============================] - 701s 8ms/sample - loss: 0.6636 - acc: 0.6029 - val_loss: 0.6420 - val_acc: 0.6377
# Epoch 3/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6450 - acc: 0.6284
# Epoch 00003: val_acc did not improve from 0.63771
# 90122/90122 [==============================] - 609s 7ms/sample - loss: 0.6450 - acc: 0.6284 - val_loss: 0.6454 - val_acc: 0.6290
# Epoch 4/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6536 - acc: 0.6117
# Epoch 00004: val_acc did not improve from 0.63771
# 90122/90122 [==============================] - 608s 7ms/sample - loss: 0.6536 - acc: 0.6117 - val_loss: 0.6736 - val_acc: 0.5914
# Epoch 5/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6614 - acc: 0.6079
# Epoch 00005: val_acc improved from 0.63771 to 0.64061, saving model to Mar-24-all-05-0.6406.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90122/90122 [==============================] - 701s 8ms/sample - loss: 0.6614 - acc: 0.6080 - val_loss: 0.6429 - val_acc: 0.6406
# Epoch 6/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6446 - acc: 0.6343
# Epoch 00006: val_acc improved from 0.64061 to 0.64105, saving model to Mar-24-all-06-0.6411.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90122/90122 [==============================] - 705s 8ms/sample - loss: 0.6446 - acc: 0.6343 - val_loss: 0.6373 - val_acc: 0.6411
# Epoch 7/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6417 - acc: 0.6394
# Epoch 00007: val_acc improved from 0.64105 to 0.64224, saving model to Mar-24-all-07-0.6422.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90122/90122 [==============================] - 708s 8ms/sample - loss: 0.6417 - acc: 0.6394 - val_loss: 0.6383 - val_acc: 0.6422
# Epoch 8/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6393 - acc: 0.6399
# Epoch 00008: val_acc improved from 0.64224 to 0.64406, saving model to Mar-24-all-08-0.6441.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90122/90122 [==============================] - 714s 8ms/sample - loss: 0.6393 - acc: 0.6399 - val_loss: 0.6363 - val_acc: 0.6441
# Epoch 9/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6357 - acc: 0.6440
# Epoch 00009: val_acc did not improve from 0.64406
# 90122/90122 [==============================] - 609s 7ms/sample - loss: 0.6357 - acc: 0.6440 - val_loss: 0.6361 - val_acc: 0.6419
# Epoch 10/20
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6341 - acc: 0.6455
# Epoch 00010: val_acc improved from 0.64406 to 0.64517, saving model to Mar-24-all-10-0.6452.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90122/90122 [==============================] - 717s 8ms/sample - loss: 0.6341 - acc: 0.6455 - val_loss: 0.6338 - val_acc: 0.6452
# Epoch 11/20
#  1792/90122 [..............................] - ETA: 8:54 - loss: 0.6119 - acc: 0.6853Buffered data was truncated after reaching the output size limit.

# %% [markdown]
# I was surprised by how bad this LSTM performed. It seems like without user features, our LSTM accuracy is capped at around 70%. I just decided to try the same architcture with only one hidden layer, in case it was too deep to get a worthwhile result or something.

# %%
def get_lstm_wv_model(load_checkpoint=False):
  model = Sequential([
        Embedding(corpus_vocab_size, embedding_length, weights=[embedding_matrix], input_length=max_len, trainable=False),
        keras.layers.Bidirectional(LSTM(64, recurrent_dropout=0.2)),
        Dense(1, activation='sigmoid')
  ])
  from keras.utils import plot_model
  plot_model(model, to_file='model.png', show_shapes=True)
  from IPython.display import Image
  Image(filename='model.png')
  if load_checkpoint:
    model.load_weights('./Mar-24-all-01-0.6957.hdf5')
  train_op = tf.train.AdamOptimizer()
  optimizer = tf.contrib.tpu.CrossShardOptimizer(train_op)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  return tf.contrib.tpu.keras_to_tpu_model(
    model,
    strategy=tf.contrib.tpu.TPUDistributionStrategy(
        tf.contrib.cluster_resolver.TPUClusterResolver(tpu_address)))

# %%
rnn_wv_scores = run_cross_validate(get_lstm_wv_model, predictors_sequences, data['deceptive'], cv=5, verbose=1, epochs=40, batch_size=32, shuffle=True)
print(rnn_wv_scores)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py:4010: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# INFO:tensorflow:Querying Tensorflow master (grpc://10.119.99.34:8470) for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, -1, 11798704124795778594)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 6325436278654816791)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 17327105947192632281)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 8193999110742063840)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 13551189176767611107)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 4452687537149654827)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 10157693069563783220)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 1122971557887119691)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 962774712908111032)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 2171603634475846081)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 17179869184, 16540263404153612352)
# WARNING:tensorflow:tpu_model (from tensorflow.contrib.tpu.python.tpu.keras_support) is experimental and may change or be removed at any time, and without warning.
# Fitting with:  (90121, 1006) labels (90121,)
# Train on 90121 samples, validate on 38624 samples
# Epoch 1/40
# INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(4,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(4, 1006), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(4, 1), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/tpu/python/tpu/keras_support.py:302: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 9.387751579284668 secs
# INFO:tensorflow:Setting weights on TPU model.
# 90080/90121 [============================>.] - ETA: 0s - loss: 0.6519 - acc: 0.6127INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(1,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(1, 1006), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(1, 1), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 12.28690218925476 secs
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.6518 - acc: 0.6127INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(4,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(4, 1006), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(4, 1), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 14.836158990859985 secs
#
# Epoch 00001: val_acc improved from -inf to 0.64944, saving model to Mar-24-all-01-0.6494.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90121/90121 [==============================] - 726s 8ms/sample - loss: 0.6518 - acc: 0.6127 - val_loss: 0.6266 - val_acc: 0.6494
# Epoch 2/40
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.6210 - acc: 0.6568
# Epoch 00002: val_acc improved from 0.64944 to 0.66197, saving model to Mar-24-all-02-0.6620.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90121/90121 [==============================] - 649s 7ms/sample - loss: 0.6210 - acc: 0.6568 - val_loss: 0.6168 - val_acc: 0.6620
# Epoch 3/40
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.6153 - acc: 0.6619
# Epoch 00003: val_acc did not improve from 0.66197
# 90121/90121 [==============================] - 641s 7ms/sample - loss: 0.6153 - acc: 0.6619 - val_loss: 0.6182 - val_acc: 0.6552
# Epoch 4/40
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.6091 - acc: 0.6674
# Epoch 00004: val_acc did not improve from 0.66197
# 90121/90121 [==============================] - 641s 7ms/sample - loss: 0.6091 - acc: 0.6674 - val_loss: 0.6207 - val_acc: 0.6562
# Epoch 5/40
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.6053 - acc: 0.6702
# Epoch 00005: val_acc did not improve from 0.66197
# 90121/90121 [==============================] - 642s 7ms/sample - loss: 0.6053 - acc: 0.6702 - val_loss: 0.6155 - val_acc: 0.6602
# Epoch 6/40
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.5990 - acc: 0.6769
# Epoch 00006: val_acc improved from 0.66197 to 0.66764, saving model to Mar-24-all-06-0.6676.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90121/90121 [==============================] - 648s 7ms/sample - loss: 0.5990 - acc: 0.6769 - val_loss: 0.6106 - val_acc: 0.6676
# Epoch 7/40
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.5924 - acc: 0.6834
# Epoch 00007: val_acc improved from 0.66764 to 0.67015, saving model to Mar-24-all-07-0.6702.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90121/90121 [==============================] - 644s 7ms/sample - loss: 0.5924 - acc: 0.6834 - val_loss: 0.6117 - val_acc: 0.6702
# Epoch 8/40
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.5848 - acc: 0.6899
# Epoch 00008: val_acc did not improve from 0.67015
# 90121/90121 [==============================] - 637s 7ms/sample - loss: 0.5847 - acc: 0.6899 - val_loss: 0.6119 - val_acc: 0.6664
# Epoch 9/40
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.5733 - acc: 0.6995
# Epoch 00009: val_acc did not improve from 0.67015
# 90121/90121 [==============================] - 638s 7ms/sample - loss: 0.5733 - acc: 0.6995 - val_loss: 0.6149 - val_acc: 0.6685
# Epoch 10/40
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.5647 - acc: 0.7059
# Epoch 00010: val_acc did not improve from 0.67015
# 90121/90121 [==============================] - 637s 7ms/sample - loss: 0.5647 - acc: 0.7059 - val_loss: 0.6173 - val_acc: 0.6673
# Epoch 11/40
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.5594 - acc: 0.7085
# Epoch 00011: val_acc did not improve from 0.67015
# 90121/90121 [==============================] - 638s 7ms/sample - loss: 0.5594 - acc: 0.7086 - val_loss: 0.6405 - val_acc: 0.6508
# Epoch 12/40
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.5783 - acc: 0.6941
# Epoch 00012: val_acc did not improve from 0.67015
# 90121/90121 [==============================] - 641s 7ms/sample - loss: 0.5783 - acc: 0.6942 - val_loss: 0.6354 - val_acc: 0.6506
# Epoch 13/40
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.6248 - acc: 0.6466
# Epoch 00013: val_acc did not improve from 0.67015
# 90121/90121 [==============================] - 644s 7ms/sample - loss: 0.6248 - acc: 0.6466 - val_loss: 0.6594 - val_acc: 0.6149
# Epoch 14/40
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.6208 - acc: 0.6523
# Epoch 00014: val_acc did not improve from 0.67015
# 90121/90121 [==============================] - 647s 7ms/sample - loss: 0.6208 - acc: 0.6523 - val_loss: 0.6550 - val_acc: 0.6241
# Epoch 15/40
# 90112/90121 [============================>.] - ETA: 0s - loss: 0.6129 - acc: 0.6623
# Epoch 00015: val_acc did not improve from 0.67015
# 90121/90121 [==============================] - 645s 7ms/sample - loss: 0.6129 - acc: 0.6623 - val_loss: 0.6506 - val_acc: 0.6299
# 32160/32188 [============================>.] - ETA: 0s - loss: 0.6502 - acc: 0.6281INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(3,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(3, 1006), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(3, 1), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 20.833635091781616 secs
# 32188/32188 [==============================] - 108s 3ms/sample - loss: 0.6503 - acc: 0.6280
# INFO:tensorflow:Querying Tensorflow master (grpc://10.119.99.34:8470) for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, -1, 11798704124795778594)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 6325436278654816791)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 17327105947192632281)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 8193999110742063840)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 13551189176767611107)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 4452687537149654827)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 10157693069563783220)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 1122971557887119691)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 962774712908111032)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 2171603634475846081)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 17179869184, 16540263404153612352)
# WARNING:tensorflow:tpu_model (from tensorflow.contrib.tpu.python.tpu.keras_support) is experimental and may change or be removed at any time, and without warning.
# Fitting with:  (90122, 1006) labels (90122,)
# Train on 90122 samples, validate on 38624 samples
# Epoch 1/40
# INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(4,), dtype=tf.int32, name='core_id_20'), TensorSpec(shape=(4, 1006), dtype=tf.float32, name='embedding_1_input_10'), TensorSpec(shape=(4, 1), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_1_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 22.592665672302246 secs
# INFO:tensorflow:Setting weights on TPU model.
# 90080/90122 [============================>.] - ETA: 0s - loss: 0.6543 - acc: 0.6102INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(1,), dtype=tf.int32, name='core_id_20'), TensorSpec(shape=(1, 1006), dtype=tf.float32, name='embedding_1_input_10'), TensorSpec(shape=(1, 1), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_1_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 27.51006245613098 secs
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6543 - acc: 0.6102INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(4,), dtype=tf.int32, name='core_id_30'), TensorSpec(shape=(4, 1006), dtype=tf.float32, name='embedding_1_input_10'), TensorSpec(shape=(4, 1), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_1_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 37.183926582336426 secs
#
# Epoch 00001: val_acc improved from -inf to 0.65739, saving model to Mar-24-all-01-0.6574.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90122/90122 [==============================] - 829s 9ms/sample - loss: 0.6543 - acc: 0.6102 - val_loss: 0.6220 - val_acc: 0.6574
# Epoch 2/40
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6176 - acc: 0.6611
# Epoch 00002: val_acc improved from 0.65739 to 0.66679, saving model to Mar-24-all-02-0.6668.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90122/90122 [==============================] - 664s 7ms/sample - loss: 0.6175 - acc: 0.6611 - val_loss: 0.6129 - val_acc: 0.6668
# Epoch 3/40
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.6038 - acc: 0.6727
# Epoch 00003: val_acc did not improve from 0.66679
# 90122/90122 [==============================] - 645s 7ms/sample - loss: 0.6038 - acc: 0.6727 - val_loss: 0.6091 - val_acc: 0.6631
# Epoch 4/40
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.5919 - acc: 0.6841
# Epoch 00004: val_acc improved from 0.66679 to 0.67021, saving model to Mar-24-all-04-0.6702.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90122/90122 [==============================] - 665s 7ms/sample - loss: 0.5919 - acc: 0.6841 - val_loss: 0.6060 - val_acc: 0.6702
# Epoch 5/40
# 90112/90122 [============================>.] - ETA: 0s - loss: 0.5812 - acc: 0.6934
# Epoch 00005: val_acc improved from 0.67021 to 0.67065, saving model to Mar-24-all-05-0.6706.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 90122/90122 [==============================] - 668s 7ms/sample - loss: 0.5812 - acc: 0.6935 - val_loss: 0.6058 - val_acc: 0.6706
# Epoch 6/40
#  1664/90122 [..............................] - ETA: 9:06 - loss: 0.5616 - acc: 0.7049Buffered data was truncated after reaching the output size limit.

# %% [markdown]
# This time it appears as though a different error occurred, due to the file being changed. However, the trend during training showed that this network would also not surpass a 70% validation accuracy. More work is needed, such as concatenating user features.
